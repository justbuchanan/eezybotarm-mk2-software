# %%
# %matplotlib notebook
from arm_model import *

from arm_gui import *
# Out:
# <img src="data:image/png;base64,...">
# Circle((0,0),r=0.005)
# Circle((0.0438406,0.0438406),r=0.005)
# Circle((-0.0410805,0.128598),r=0.005)
# Circle((-0.00361947,0.170223),r=0.005)
# Circle((-0.139416,0.0193312),r=0.005)
